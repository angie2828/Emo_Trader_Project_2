# %%
import twint
import pandas as pd
import numpy as np
import nest_asyncio
nest_asyncio.apply()

# %%
list = ["inflation_guy", "cnbc", "dylanmatt", "bloomberg", "wsj"]
for tweets in list:
    print(list)
    c = twint.Config()
    c.Search = "inflation"
    c.Hide_output = True
    c.Lang= "en"
    c.Pandas = True
    c.Since = "2016-01-01"
    c.near = "united_states"
    c.Limit = 1000
    twint.run.Search(c)
data = twint.output.panda.Tweets_df
data.head()
# Out:
# ['inflation_guy', 'cnbc', 'dylanmatt', 'bloomberg', 'wsj']
# ['inflation_guy', 'cnbc', 'dylanmatt', 'bloomberg', 'wsj']
# ['inflation_guy', 'cnbc', 'dylanmatt', 'bloomberg', 'wsj']
# ['inflation_guy', 'cnbc', 'dylanmatt', 'bloomberg', 'wsj']
# ['inflation_guy', 'cnbc', 'dylanmatt', 'bloomberg', 'wsj']
#                     id      conversation_id    created_at  \
# 0  1442172170646458369  1442172170646458369  1.632676e+12
# 1  1442172129210888204  1442172129210888204  1.632676e+12
# 2  1442172122609160196  1442172122609160196  1.632676e+12
# 3  1442172118192381956  1442172118192381956  1.632676e+12
# 4  1442172117034881029  1442172117034881029  1.632676e+12
#
#                   date timezone place  \
# 0  2021-09-26 13:00:14    -0400
# 1  2021-09-26 13:00:04    -0400
# 2  2021-09-26 13:00:02    -0400
# 3  2021-09-26 13:00:01    -0400
# 4  2021-09-26 13:00:01    -0400
#
#                                                tweet language  \
# 0  Although the #NorthEast is up by 15% YoY, #pro...       en
# 1  26/09, Five cost of living crises facing the U...       en
# 2  Our incomes destroyed by the world’s worst inf...       en
# 3  This week if both so called "Bills" pass, you ...       en
# 4  Don’t be fooled #inflation is not transitory! ...       en
#
#                                             hashtags cashtags  ...  geo  \
# 0                      [northeast, property, prices]       []  ...
# 1                                                 []       []  ...
# 2                                    [lebanonprayer]       []  ...
# 3                                                 []       []  ...
# 4  [inflation, goldcoretv, gold, silver, precious...       []  ...
#
#   source user_rt_id user_rt  retweet_id reply_to retweet_date translate  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %%
Tweets_df
# Out:
#                     date                                              tweet  \
# 0    2021-09-26 12:55:22  @FedResearch Very interesting discussion on in...
# 1    2021-09-26 12:55:15  Inflation: Der fatale Irrglaube der EZB // Int...
# 2    2021-09-26 12:55:00  "Central banks often disregard food&amp;fuel i...
# 3    2021-09-26 12:54:59  what Americans seldom think about but feel is ...
# 4    2021-09-26 12:54:53  @Gator_NY I have 20 years in the industry. The...
# ..                   ...                                                ...
# 109  2021-09-26 12:38:52  @PeterRo18785637 @MarinaPurkiss Misleading tro...
# 110  2021-09-26 12:38:51  @TorstenBell @theobertram @RachelReevesMP Labo...
# 111  2021-09-26 12:38:51  @ScientixFinance If there are 50,000 scix toke...
# 112  2021-09-26 12:38:51  1) Vote for BJP :   - Means Corruption, Rise i...
# 113  2021-09-26 12:38:42  Company defaults in China aren’t a potential c...
#
#     hashtags                                     name  nlikes  nreplies  \
# 0         []                         Fernando Colunga       0         0
# 1      [btc]                         Gabriel Kunzer 🟩       1         0
# 2         []                                   Michał       0         0
# 3         []                      les aaron friedlieb       0         0
# 4         []                                   Angelo       0         0
# ..       ...                                      ...     ...       ...
# 109       []  knowgum #FBPA #NHSLove #FBPE #GTTO 3.5%       1         1
# 110       []                              Barry Dolan       0         0
# 111       []                                Aelox.com       0         0
# 112       []                                 Sourcasm       6         0
# 113       []                       Raymond lee veazey       0         0
#
#      nretweets
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 109          0
# 110          0
# 111          0
# 112          2
# 113          0
#
# [114 rows x 7 columns]

# %%
Tweets_df = twint.storage.panda.Tweets_df

# %%
Tweets_df
# Out:
#                        id      conversation_id    created_at  \
# 0     1442172170646458369  1442172170646458369  1.632676e+12
# 1     1442172129210888204  1442172129210888204  1.632676e+12
# 2     1442172122609160196  1442172122609160196  1.632676e+12
# 3     1442172118192381956  1442172118192381956  1.632676e+12
# 4     1442172117034881029  1442172117034881029  1.632676e+12
# ...                   ...                  ...           ...
# 1010  1442137737386074113  1442128367285727242  1.632667e+12
# 1011  1442137721850499074  1442130184761593861  1.632667e+12
# 1012  1442137677474631688  1441819746127724545  1.632667e+12
# 1013  1442137654296858632  1442137654296858632  1.632667e+12
# 1014  1442137632880807936  1442137632880807936  1.632667e+12
#
#                      date timezone place  \
# 0     2021-09-26 13:00:14    -0400
# 1     2021-09-26 13:00:04    -0400
# 2     2021-09-26 13:00:02    -0400
# 3     2021-09-26 13:00:01    -0400
# 4     2021-09-26 13:00:01    -0400
# ...                   ...      ...   ...
# 1010  2021-09-26 10:43:24    -0400
# 1011  2021-09-26 10:43:21    -0400
# 1012  2021-09-26 10:43:10    -0400
# 1013  2021-09-26 10:43:05    -0400
# 1014  2021-09-26 10:42:59    -0400
#
#                                                   tweet language  \
# 0     Although the #NorthEast is up by 15% YoY, #pro...       en
# 1     26/09, Five cost of living crises facing the U...       en
# 2     Our incomes destroyed by the world’s worst inf...       en
# 3     This week if both so called "Bills" pass, you ...       en
# 4     Don’t be fooled #inflation is not transitory! ...       en
# ...                                                 ...      ...
# 1010  @gmangeegee @TomCottonAR @KellyannePolls Great...       en
# 1011  @EJDionne The focus on the top line number, wi...       en
# 1012  @ChristianM_28 @AndrewYang You think UBI will ...       en
# 1013  Reminder: You can’t be bullish energy without ...       en
# 1014  A hamster has been #trading #cryptocurrencies ...       en
#
#                                                hashtags cashtags  ...  geo  \
# 0                         [northeast, property, prices]       []  ...
# 1                                                    []       []  ...
# 2                                       [lebanonprayer]       []  ...
# 3                                                    []       []  ...
# 4     [inflation, goldcoretv, gold, silver, precious...       []  ...
# ...                                                 ...      ...  ...  ...
# 1010                                                 []       []  ...
# 1011                                                 []       []  ...
# 1012                                                 []       []  ...
# 1013                                                 []       []  ...
# 1014  [trading, cryptocurrencies, tokens, bitcoin, b...    [spy]  ...
#
#      source user_rt_id user_rt  retweet_id  \
# 0
# 1
# 2
# 3
# 4
# ...     ...        ...     ...         ...
# 1010
# 1011
# 1012
# 1013
# 1014
#
#                                                reply_to retweet_date  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...          ...
# 1010  [{'screen_name': 'gmangeegee', 'name': 'Graeme...
# 1011  [{'screen_name': 'EJDionne', 'name': 'EJ Dionn...
# 1012  [{'screen_name': 'ChristianM_28', 'name': 'Chr...
# 1013                                                 []
# 1014                                                 []
#
#      translate trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
# ...        ...       ...         ...
# 1010
# 1011
# 1012
# 1013
# 1014
#
# [1015 rows x 38 columns]

# %%
Tweets_df['hashtags']
# Out:
# 0                           [northeast, property, prices]
# 1                                                      []
# 2                                         [lebanonprayer]
# 3                                                      []
# 4       [inflation, goldcoretv, gold, silver, precious...
#                               ...
# 1010                                                   []
# 1011                                                   []
# 1012                                                   []
# 1013                                                   []
# 1014    [trading, cryptocurrencies, tokens, bitcoin, b...
# Name: hashtags, Length: 1015, dtype: object

# %%
Tweets_df.drop(['id', 'conversation_id', 'created_at', 'timezone', 'place', 'language','cashtags', 'user_id', 'user_id_str','username', 'day', 'hour', 'link', 'urls', 'photos', 'video', 'thumbnail', 'retweet', 'quote_url', 'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
       'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
       'trans_dest'], axis = 1, inplace = True)

# %%
Tweets_df
# Out:
#                      date                                              tweet  \
# 0     2021-09-26 13:00:14  Although the #NorthEast is up by 15% YoY, #pro...
# 1     2021-09-26 13:00:04  26/09, Five cost of living crises facing the U...
# 2     2021-09-26 13:00:02  Our incomes destroyed by the world’s worst inf...
# 3     2021-09-26 13:00:01  This week if both so called "Bills" pass, you ...
# 4     2021-09-26 13:00:01  Don’t be fooled #inflation is not transitory! ...
# ...                   ...                                                ...
# 1010  2021-09-26 10:43:24  @gmangeegee @TomCottonAR @KellyannePolls Great...
# 1011  2021-09-26 10:43:21  @EJDionne The focus on the top line number, wi...
# 1012  2021-09-26 10:43:10  @ChristianM_28 @AndrewYang You think UBI will ...
# 1013  2021-09-26 10:43:05  Reminder: You can’t be bullish energy without ...
# 1014  2021-09-26 10:42:59  A hamster has been #trading #cryptocurrencies ...
#
#                                                hashtags             name  \
# 0                         [northeast, property, prices]     katefaulkner
# 1                                                    []       Daily Tory
# 2                                       [lebanonprayer]    Jayson Casper
# 3                                                    []         D. Craig
# 4     [inflation, goldcoretv, gold, silver, precious...         GoldCore
# ...                                                 ...              ...
# 1010                                                 []    Sorry Charlie
# 1011                                                 []  ContraFictional
# 1012                                                 []  selekedi mafate
# 1013                                                 []  Christian Klein
# 1014  [trading, cryptocurrencies, tokens, bitcoin, b...   Zakaria Bziker
#
#       nlikes  nreplies  nretweets
# 0          0         0          0
# 1          0         0          0
# 2          0         0          0
# 3          1         0          0
# 4          0         0          0
# ...      ...       ...        ...
# 1010       0         1          0
# 1011       0         0          0
# 1012       0         1          0
# 1013      10         2          2
# 1014       1         0          0
#
# [1015 rows x 7 columns]
